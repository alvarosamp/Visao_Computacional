# %%
import pyscreenshot as ImageGrab

im= ImageGrab.grab()

im.save('fullscreen.png')

# %% [markdown]
# ##capture video from screen

# %%
import numpy as np
from PIL import ImageGrab
import cv2
import time
last_time = time.time()

while(True):
    frame = np.array(ImageGrab.grab(bbox = (0, 0, 300, 300)))
    FPS = 1.0/ (time.time() - last_time)
    print(f' Fps = {FPS}')
    last_time = time.time()
    
    cv2.imshow('window', cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        print("Exited...")
        break
        
cv2.destroyAllWindows()
# Out:
#  Fps = 21.651149585488483
#  Fps = 8.30103211122656
#  Fps = 24.410892731389062
#  Fps = 19.22951796733878
#  Fps = 21.289802548094006
#  Fps = 20.336512400300613
#  Fps = 22.080513805901397
#  Fps = 17.7071980411196
#  Fps = 12.977506048923571
#  Fps = 17.145851814001023
#  Fps = 14.970835043635
#  Fps = 24.28819438412406
#  Fps = 17.18716424148797
#  Fps = 19.91020644542654
#  Fps = 15.390585783270465
#  Fps = 14.913929325757199
#  Fps = 19.70525999285889
#  Fps = 19.40127759763538
#  Fps = 19.872378732315624
#  Fps = 20.40924529219989
#  Fps = 19.835538698724072
#  Fps = 18.91029756537421
#  Fps = 7.857665539496239
#  Fps = 23.47934929858149
#  Fps = 19.607431023682416
#  Fps = 18.881779098296082
#  Fps = 21.677446029965836
#  Fps = 30.540900286891812
#  Fps = 20.406266420161526
#  Fps = 29.411834004179347
#  Fps = 20.007078767989086
#  Fps = 22.715502721438437
#  Fps = 26.285041047816005
#  Fps = 21.27651889840869
#  Fps = 19.218504144462823
#  Fps = 33.35775467841606
#  Fps = 20.00278511679368
#  Fps = 27.75038374000953
#  Fps = 33.28548527894611
#  Fps = 31.171206254598424
#  Fps = 3.2592307094568342
#  Fps = 11.362735961509287
#  Fps = 20.409841170974776
#  Fps = 19.607797671918096
#  Fps = 23.254404932193427
#  Fps = 17.54337005713521
#  Fps = 22.203950259133187
#  Fps = 20.35743788616387
#  Fps = 22.848277515089446
#  Fps = 27.026025322980765
#  Fps = 18.868018911636234
#  Fps = 32.20788475419655
#  Fps = 20.153005674529005
#  Fps = 33.219315544784216
#  Fps = 18.031873777433848
#  Fps = 17.71385372981785
#  Fps = 18.816554137412798
#  Fps = 15.848194819670892
#  Fps = 22.44611770246333
#  Fps = 20.835050419750633
#  Fps = 22.19044091972023
#  Fps = 20.004216129078415
#  Fps = 18.96056271811656
#  Fps = 30.616251569388886
#  Fps = 27.029160249263743
#  Fps = 21.69549879478187
#  Fps = 20.832980678488056
#  Fps = 19.662581921486634
#  Fps = 19.23022328183027
#  Fps = 31.795745713116123
#  Fps = 27.612634794401508
#  Fps = 21.888997322784512
#  Fps = 20.108946730015965
#  Fps = 19.59414927660131
#  Fps = 19.12901342673672
#  Fps = 30.646227586912364
#  Fps = 30.045588045674005
#  Fps = 21.730568767032445
#  Fps = 18.516753931324335
#  Fps = 20.007078767989086
#  Fps = 21.747018686355435
#  Fps = 30.29340729184723
#  Fps = 31.230856291883843
#  Fps = 27.778871308505916
#  Fps = 20.194632488179725
#  Fps = 30.932814136318715
#  Fps = 20.12303234132791
#  Fps = 30.98811986524026
#  Fps = 29.636278846289727
#  Fps = 31.04753021992257
#  Fps = 30.425255338904364
#  Fps = 30.703883459609823
#  Fps = 18.940698325536026
#  Fps = 19.60229938776464
#  Fps = 32.04914763392959
#  Fps = 31.29960822357375
#  Fps = 30.301723764250315
#  Fps = 29.398228103622294
#  Fps = 20.00183122234091
#  Fps = 20.023889432602104
#  Fps = 20.003357497138495
#  Fps = 31.249936670193268
#  Fps = 26.30795767447987
#  Fps = 22.2251283654534
#  Fps = 24.58992788884329
#  Fps = 20.263610758163555
#  Fps = 22.21324012286834
#  Fps = 18.524277676197542
#  Fps = 33.93312568261802
#  Fps = 26.564217539726272
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       5 last_time = time.time()
#       7 while(True):
# ----> 8     frame = np.array(ImageGrab.grab(bbox = (0, 0, 300, 300)))
#       9     FPS = 1.0/ (time.time() - last_time)
#      10     print(f' Fps = {FPS}')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\PIL\ImageGrab.py:50, in grab(bbox, include_layered_windows, all_screens, xdisplay)
#      46 elif sys.platform == "win32":
#      47     offset, size, data = Image.core.grabscreen_win32(
#      48         include_layered_windows, all_screens
#      49     )
# ---> 50     im = Image.frombytes(
#      51         "RGB",
#      52         size,
#      53         data,
#      54         # RGB, 32-bit line padding, origin lower left corner
#      55         "raw",
#      56         "BGR",
#      57         (size[0] * 3 + 3) & -4,
#      58         -1,
#      59     )
#      60     if bbox:
#      61         x0, y0 = offset
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\PIL\Image.py:2942, in frombytes(mode, size, data, decoder_name, *args)
#    2938         color = im.palette.getcolor(color)
#    2939     return im._new(core.fill(mode, size, color))
# -> 2942 def frombytes(mode, size, data, decoder_name="raw", *args):
#    2943     """
#    2944     Creates a copy of an image memory from pixel data in a buffer.
#    2945
#    (...)
#    2963     :returns: An :py:class:`~PIL.Image.Image` object.
#    2964     """
#    2966     _check_size(size)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Se precisar de um frame mais rapido

# %%
import numpy as np
import cv2
from mss import mss
from PIL import Image
import time

bounding_box = {'top': 100, 'left': 0, 'width': 400, 'height': 300}

sct = mss()
frame_count = 0 
last_time = time.time()

while True:
    frame_count += 1
    sct_img = sct.grab(bounding_box)
    cv2.imshow('screen', np.array(sct_img))

    # Display FPS rate
    if frame_count % 30 == 0:
        FPS = 1.0 / (time.time()-last_time)
        print('FPS = {}'.format(FPS))
    last_time = time.time()    

    if cv2.waitKey(1) == 13: #13 is the Enter Key
        print("Exited...")
        break
        
cv2.destroyAllWindows()
