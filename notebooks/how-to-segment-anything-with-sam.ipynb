# %% [markdown]
# <a href="https://colab.research.google.com/github/alvarosamp/Visao_Computacional/blob/main/notebooks/how-to-segment-anything-with-sam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # Segment Anything Model (SAM)
#
# ---
#
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/facebookresearch/segment-anything) [![arXiv](https://img.shields.io/badge/arXiv-2304.02643-b31b1b.svg)](https://arxiv.org/abs/2304.02643)
#
# Segment Anything Model (SAM): a new AI model from Meta AI that can "cut out" any object, in any image, with a single click. SAM is a promptable segmentation system with zero-shot generalization to unfamiliar objects and images, without the need for additional training. This notebook is an extension of the [official notebook](https://colab.research.google.com/github/facebookresearch/segment-anything/blob/main/notebooks/automatic_mask_generator_example.ipynb) prepared by Meta AI.
#
# ![segment anything model](https://media.roboflow.com/notebooks/examples/segment-anything-model-paper.png)
#
# ## Complementary Materials
#
# ---
#
# [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/notebooks/blob/main/notebooks/how-to-segment-anything-with-sam.ipynb) [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/D-D6ZmadzPE) [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/how-to-use-segment-anything-model-sam)
#
# We recommend that you follow along in this notebook while reading the blog post on Segment Anything Model.
#
# ![segment anything model blogpost](https://media.roboflow.com/notebooks/examples/segment-anything-model-blogpost.png)
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - **Before you start** - Make sure you have access to the GPU
# - Install Segment Anything Model (SAM)
# - Download Example Data
# - Load Model
# - Automated Mask Generation
# - Generate Segmentation with Bounding Box
# - Segment Anything in Roboflow Universe Dataset
#
# ## Let's begin!

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/AlvaroSampaio/Sam1.2
# !ls
# Out:
# /content/drive/MyDrive/AlvaroSampaio/Sam1.2
# Floresta-3

# %%
import os
HOME = os.getcwd()
print(HOME)
# %cd {HOME}
# Out:
# /content/drive/MyDrive/AlvaroSampaio/Sam1.2

# %%
# !nvidia-smi
# Out:
# Tue Jan 14 13:46:25 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0              47W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print("HOME:", HOME)
# Out:
# HOME: /content/drive/MyDrive/AlvaroSampaio/Sam1.2

# %% [markdown]
# ## Install Segment Anything Model (SAM) and other dependencies

# %%
# !pip install -q 'git+https://github.com/facebookresearch/segment-anything.git'
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for segment_anything (setup.py) ... done

# %%
# !pip install -q jupyter_bbox_widget roboflow dataclasses-json supervision==0.23.0
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.7/213.7 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.4/727.4 kB 33.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 71.7 MB/s eta 0:00:00

# %% [markdown]
# ### Download SAM weights

# %%
# !mkdir -p {HOME}/weights
# !wget -q https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth -P {HOME}/weights

# %%
import os

CHECKPOINT_PATH = os.path.join(HOME, "weights", "sam_vit_h_4b8939.pth")
print(CHECKPOINT_PATH, "; exist:", os.path.isfile(CHECKPOINT_PATH))
# Out:
# /content/drive/MyDrive/AlvaroSampaio/Sam1.2/weights/sam_vit_h_4b8939.pth ; exist: True

# %% [markdown]
# ## Download Example Data
#
# **NONE:** Let's download few example images. Feel free to use your images or videos.

# %%
# !mkdir -p {HOME}/data

# !wget -q https://media.roboflow.com/notebooks/examples/dog.jpeg -P {HOME}/data
# !wget -q https://media.roboflow.com/notebooks/examples/dog-2.jpeg -P {HOME}/data
# !wget -q https://media.roboflow.com/notebooks/examples/dog-3.jpeg -P {HOME}/data
# !wget -q https://media.roboflow.com/notebooks/examples/dog-4.jpeg -P {HOME}/data

# %% [markdown]
# ## Load Model

# %%
import torch

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
MODEL_TYPE = "vit_h"

# %%
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)
# Out:
# /usr/local/lib/python3.10/dist-packages/segment_anything/build_sam.py:105: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(f)

# %% [markdown]
# ## Automated Mask Generation
#
# To run automatic mask generation, provide a SAM model to the `SamAutomaticMaskGenerator` class. Set the path below to the SAM checkpoint. Running on CUDA and with the default model is recommended.

# %%
mask_generator = SamAutomaticMaskGenerator(sam)

# %%
import os

IMAGE_NAME = "dog.jpeg"
IMAGE_PATH = os.path.join(HOME, "data", IMAGE_NAME)

# %% [markdown]
# ### Generate masks with SAM

# %%
import cv2
import supervision as sv

image_bgr = cv2.imread(IMAGE_PATH)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

sam_result = mask_generator.generate(image_rgb)

# %% [markdown]
# ### Output format

# %% [markdown]
# `SamAutomaticMaskGenerator` returns a `list` of masks, where each mask is a `dict` containing various information about the mask:
#
# * `segmentation` - `[np.ndarray]` - the mask with `(W, H)` shape, and `bool` type
# * `area` - `[int]` - the area of the mask in pixels
# * `bbox` - `[List[int]]` - the boundary box of the mask in `xywh` format
# * `predicted_iou` - `[float]` - the model's own prediction for the quality of the mask
# * `point_coords` - `[List[List[float]]]` - the sampled input point that generated this mask
# * `stability_score` - `[float]` - an additional measure of mask quality
# * `crop_box` - `List[int]` - the crop of the image used to generate this mask in `xywh` format

# %%
print(sam_result[0].keys())
# Out:
# dict_keys(['segmentation', 'area', 'bbox', 'predicted_iou', 'point_coords', 'stability_score', 'crop_box'])

# %% [markdown]
# ### Results visualisation with Supervision
#
# As of version `0.5.0` Supervision has native support for SAM.

# %%
mask_annotator = sv.MaskAnnotator(color_lookup=sv.ColorLookup.INDEX)

detections = sv.Detections.from_sam(sam_result=sam_result)

annotated_image = mask_annotator.annotate(scene=image_bgr.copy(), detections=detections)

sv.plot_images_grid(
    images=[image_bgr, annotated_image],
    grid_size=(1, 2),
    titles=['source image', 'segmented image']
)

# %% [markdown]
# ### Interaction with segmentation results

# %%
masks = [
    mask['segmentation']
    for mask
    in sorted(sam_result, key=lambda x: x['area'], reverse=True)
]

sv.plot_images_grid(
    images=masks,
    grid_size=(8, int(len(masks) / 8)),
    size=(16, 16)
)

# %% [markdown]
# ## Generate Segmentation with Bounding Box
#
# The `SamPredictor` class provides an easy interface to the model for prompting the model. It allows the user to first set an image using the `set_image` method, which calculates the necessary image embeddings. Then, prompts can be provided via the `predict` method to efficiently predict masks from those prompts. The model can take as input both point and box prompts, as well as masks from the previous iteration of prediction.

# %%
mask_predictor = SamPredictor(sam)

# %%
import os

IMAGE_NAME = "dog.jpeg"
IMAGE_PATH = os.path.join(HOME, "data", IMAGE_NAME)

# %% [markdown]
# ### Draw Box

# %%
# helper function that loads an image before adding it to the widget

import base64

def encode_image(filepath):
    with open(filepath, 'rb') as f:
        image_bytes = f.read()
    encoded = str(base64.b64encode(image_bytes), 'utf-8')
    return "data:image/jpg;base64,"+encoded

# %% [markdown]
# **NOTE:** Execute cell below and use your mouse to draw bounding box on the image 👇

# %%
IS_COLAB = True

if IS_COLAB:
    from google.colab import output
    output.enable_custom_widget_manager()

from jupyter_bbox_widget import BBoxWidget

widget = BBoxWidget()
widget.image = encode_image(IMAGE_PATH)
widget
# Out:
# BBoxWidget(colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#b…

# %%
widget.bboxes
# Out:
# []

# %% [markdown]
# ### Generate masks with SAM

# %% [markdown]
# **NOTE:** `SamPredictor.predict` method takes `np.ndarray` `box` argument in `[x_min, y_min, x_max, y_max]` format. Let's reorganise your data first

# %%
import numpy as np

# default_box is going to be used if you will not draw any box on image above
default_box = {'x': 68, 'y': 247, 'width': 555, 'height': 678, 'label': ''}

box = widget.bboxes[0] if widget.bboxes else default_box
box = np.array([
    box['x'],
    box['y'],
    box['x'] + box['width'],
    box['y'] + box['height']
])

# %%
import cv2
import numpy as np
import supervision as sv

image_bgr = cv2.imread(IMAGE_PATH)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

mask_predictor.set_image(image_rgb)

masks, scores, logits = mask_predictor.predict(
    box=box,
    multimask_output=True
)

# %% [markdown]
# ### Results visualisation with Supervision

# %%
box_annotator = sv.BoxAnnotator(color=sv.Color.RED, color_lookup=sv.ColorLookup.INDEX)
mask_annotator = sv.MaskAnnotator(color=sv.Color.RED, color_lookup=sv.ColorLookup.INDEX)

detections = sv.Detections(
    xyxy=sv.mask_to_xyxy(masks=masks),
    mask=masks
)
detections = detections[detections.area == np.max(detections.area)]

source_image = box_annotator.annotate(scene=image_bgr.copy(), detections=detections)
segmented_image = mask_annotator.annotate(scene=image_bgr.copy(), detections=detections)

sv.plot_images_grid(
    images=[source_image, segmented_image],
    grid_size=(1, 2),
    titles=['source image', 'segmented image']
)

# %% [markdown]
# ### Interaction with segmentation results

# %%
import supervision as v

sv.plot_images_grid(
    images=masks,
    grid_size=(1, 4),
    size=(16, 4)
)

# %% [markdown]
# ## Segment Anything in Roboflow Universe Dataset

# %% [markdown]
# ### Utils Supporting Dataset Processing
#
# A couple of helper functions that, unfortunately, we have to write ourselves to facilitate the processing of COCO annotations.

# %%
import numpy as np
from dataclasses import dataclass
from typing import List, Tuple, Union, Optional
from dataclasses_json import dataclass_json
from supervision import Detections


@dataclass_json
@dataclass
class COCOCategory:
    id: int
    name: str
    supercategory: str


@dataclass_json
@dataclass
class COCOImage:
    id: int
    width: int
    height: int
    file_name: str
    license: int
    date_captured: str
    coco_url: Optional[str] = None
    flickr_url: Optional[str] = None


@dataclass_json
@dataclass
class COCOAnnotation:
    id: int
    image_id: int
    category_id: int
    segmentation: List[List[float]]
    area: float
    bbox: Tuple[float, float, float, float]
    iscrowd: int


@dataclass_json
@dataclass
class COCOLicense:
    id: int
    name: str
    url: str


@dataclass_json
@dataclass
class COCOJson:
    images: List[COCOImage]
    annotations: List[COCOAnnotation]
    categories: List[COCOCategory]
    licenses: List[COCOLicense]


def load_coco_json(json_file: str) -> COCOJson:
    import json

    with open(json_file, "r") as f:
        json_data = json.load(f)

    return COCOJson.from_dict(json_data)


class COCOJsonUtility:
    @staticmethod
    def get_annotations_by_image_id(coco_data: COCOJson, image_id: int) -> List[COCOAnnotation]:
        return [annotation for annotation in coco_data.annotations if annotation.image_id == image_id]

    @staticmethod
    def get_annotations_by_image_path(coco_data: COCOJson, image_path: str) -> Optional[List[COCOAnnotation]]:
        image = COCOJsonUtility.get_image_by_path(coco_data, image_path)
        if image:
            return COCOJsonUtility.get_annotations_by_image_id(coco_data, image.id)
        else:
            return None

    @staticmethod
    def get_image_by_path(coco_data: COCOJson, image_path: str) -> Optional[COCOImage]:
        for image in coco_data.images:
            if image.file_name == image_path:
                return image
        return None

    @staticmethod
    def annotations2detections(annotations: List[COCOAnnotation]) -> Detections:
        class_id, xyxy = [], []

        for annotation in annotations:
            x_min, y_min, width, height = annotation.bbox
            class_id.append(annotation.category_id)
            xyxy.append([
                x_min,
                y_min,
                x_min + width,
                y_min + height
            ])

        return Detections(
            xyxy=np.array(xyxy, dtype=int),
            class_id=np.array(class_id, dtype=int)
        )

# %% [markdown]
# ### Download Dataset from Roboflow

# %%
# %cd {HOME}

import roboflow
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="aJO0DguOcxOKKsVf2mq5")
project = rf.workspace("alvaro-z5qmu").project("floresta-wgiln")
version = project.version(3)
dataset = version.download("coco")
# Out:
# /content/drive/MyDrive/AlvaroSampaio/Sam1.2
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.50)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from roboflow) (2024.12.14)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (11.1.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.55.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.4.1)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Floresta-3 to coco:: 100%|██████████| 1200446/1200446 [01:14<00:00, 16191.74it/s]
# Extracting Dataset Version Zip to Floresta-3 in coco:: 100%|██████████| 14656/14656 [01:45<00:00, 138.87it/s]

# %%
import os

DATA_SET_SUBDIRECTORY = "/content/drive/MyDrive/AlvaroSampaio/Sam1.2/Floresta-3/test"
ANNOTATIONS_FILE_NAME = "_annotations.coco.json"
IMAGES_DIRECTORY_PATH = os.path.join(dataset.location, DATA_SET_SUBDIRECTORY)
ANNOTATIONS_FILE_PATH = os.path.join(dataset.location, DATA_SET_SUBDIRECTORY, ANNOTATIONS_FILE_NAME)

# %%
coco_data = load_coco_json(json_file=ANNOTATIONS_FILE_PATH)

CLASSES = [
    category.name
    for category
    in coco_data.categories
    if category.supercategory != 'none'
]

IMAGES = [
    image.file_name
    for image
    in coco_data.images
]

# %%
CLASSES
# Out:
# ['Floresta']

# %% [markdown]
# ### Single Image Bounding Box to Mask

# %%
# set random seed to allow easy reproduction of the experiment

import random
random.seed(42)

# %%
EXAMPLE_IMAGE_NAME = random.choice(IMAGES)
EXAMPLE_IMAGE_PATH = os.path.join(dataset.location, DATA_SET_SUBDIRECTORY, EXAMPLE_IMAGE_NAME)

# load dataset annotations
annotations = COCOJsonUtility.get_annotations_by_image_path(coco_data=coco_data, image_path=EXAMPLE_IMAGE_NAME)
ground_truth = COCOJsonUtility.annotations2detections(annotations=annotations)

# small hack - coco numerate classes from 1, model from 0 + we drop first redundant class from coco json
ground_truth.class_id = ground_truth.class_id - 1

# load image
image_bgr = cv2.imread(EXAMPLE_IMAGE_PATH)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# initiate annotator
box_annotator = sv.BoxAnnotator(color=sv.Color.RED, color_lookup=sv.ColorLookup.INDEX)
mask_annotator = sv.MaskAnnotator(color=sv.Color.RED, color_lookup=sv.ColorLookup.INDEX)

# annotate ground truth
annotated_frame_ground_truth = box_annotator.annotate(scene=image_bgr.copy(), detections=ground_truth)

# run SAM inference
mask_predictor.set_image(image_rgb)

masks, scores, logits = mask_predictor.predict(
    box=ground_truth.xyxy[0],
    multimask_output=True
)

detections = sv.Detections(
    xyxy=sv.mask_to_xyxy(masks=masks),
    mask=masks
)
detections = detections[detections.area == np.max(detections.area)]

annotated_image = mask_annotator.annotate(scene=image_bgr.copy(), detections=detections)

sv.plot_images_grid(
    images=[annotated_frame_ground_truth, annotated_image],
    grid_size=(1, 2),
    titles=['source image', 'segmented image']
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-fbc01c3eb07d> in <cell line: 34>()
#      32     mask=masks
#      33 )
# ---> 34 detections = detections[detections.area]
#      35
#      36 annotated_image = mask_annotator.annotate(scene=image_bgr.copy(), detections=detections)
#
# /usr/local/lib/python3.10/dist-packages/supervision/detection/core.py in __getitem__(self, index)
#    1079             index = [index]
#    1080         return Detections(
# -> 1081             xyxy=self.xyxy[index],
#    1082             mask=self.mask[index] if self.mask is not None else None,
#    1083             confidence=self.confidence[index] if self.confidence is not None else None,
#
# IndexError: index 24664 is out of bounds for axis 0 with size 3

# %%
import numpy as np
import cv2
import supervision as sv

# Escolher uma imagem aleatória do dataset
EXAMPLE_IMAGE_NAME = random.choice(IMAGES)
EXAMPLE_IMAGE_PATH = os.path.join(dataset.location, DATA_SET_SUBDIRECTORY, EXAMPLE_IMAGE_NAME)

# Carregar anotações do dataset
annotations = COCOJsonUtility.get_annotations_by_image_path(coco_data=coco_data, image_path=EXAMPLE_IMAGE_NAME)
ground_truth = COCOJsonUtility.annotations2detections(annotations=annotations)

# Ajustar classes (COCO começa do 1, enquanto o modelo usa 0)
ground_truth.class_id = ground_truth.class_id - 1

# Carregar imagem
image_bgr = cv2.imread(EXAMPLE_IMAGE_PATH)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Inicializar anotadores
box_annotator = sv.BoxAnnotator(color=sv.Color.RED, color_lookup=sv.ColorLookup.INDEX)
mask_annotator = sv.MaskAnnotator(color=sv.Color.RED, color_lookup=sv.ColorLookup.INDEX)

# Anotar as caixas delimitadoras (ground truth)
annotated_frame_ground_truth = box_annotator.annotate(scene=image_bgr.copy(), detections=ground_truth)

# Configurar o SAM para a imagem carregada
mask_predictor.set_image(image_rgb)

# Inicializar listas para armazenar todas as máscaras e caixas delimitadoras
all_masks = []
all_boxes = []

# Processar cada caixa do ground truth e aplicar o SAM
for box in ground_truth.xyxy:
    masks, scores, logits = mask_predictor.predict(
        box=box,
        multimask_output=True
    )
    # Adicionar as máscaras e as caixas delimitadoras às listas
    all_masks.extend(masks)  # Adicionar máscaras
    all_boxes.extend(sv.mask_to_xyxy(masks=masks))  # Converter máscaras em caixas delimitadoras

# Criar um único objeto Detections combinando todas as máscaras e caixas
all_detections = sv.Detections(
    xyxy=np.array(all_boxes),  # Todas as caixas delimitadoras
    mask=np.array(all_masks)  # Todas as máscaras
)

# Anotar todas as segmentações na imagem original
annotated_image = mask_annotator.annotate(scene=image_bgr.copy(), detections=all_detections)

# Exibir as imagens lado a lado: uma com ground truth e outra com segmentações
sv.plot_images_grid(
    images=[annotated_frame_ground_truth, annotated_image],
    grid_size=(1, 2),
    titles=['source image', 'segmented image']
)

# %%
import os
import numpy as np
import cv2
import supervision as sv

# Configurações de pastas
INPUT_FOLDER = "/content/drive/MyDrive/AlvaroSampaio/Sam1.2/Floresta-3/valid"  # Pasta com as imagens a serem processadas
OUTPUT_FOLDER = "/content/drive/MyDrive/AlvaroSampaio/Sam1.2/Predicao"  # Pasta para salvar os resultados
MASKS_FOLDER = os.path.join(OUTPUT_FOLDER, "masks")  # Pasta para salvar as máscaras segmentadas

# Criar pastas de saída, se não existirem
os.makedirs(OUTPUT_FOLDER, exist_ok=True)
os.makedirs(MASKS_FOLDER, exist_ok=True)

# Inicializar anotadores
box_annotator = sv.BoxAnnotator(color=sv.Color.RED, color_lookup=sv.ColorLookup.INDEX)
mask_annotator = sv.MaskAnnotator(color=sv.Color.RED, color_lookup=sv.ColorLookup.INDEX)

# Processar todas as imagens na pasta de entrada
for filename in os.listdir(INPUT_FOLDER):
    if filename.endswith((".png", ".jpg", ".jpeg")):  # Apenas arquivos de imagem
        print(f"Processando: {filename}")

        # Caminhos para a imagem de entrada e saída
        input_path = os.path.join(INPUT_FOLDER, filename)
        output_path = os.path.join(OUTPUT_FOLDER, f"annotated_{filename}")

        # Carregar imagem
        image_bgr = cv2.imread(input_path)
        image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

        # Configurar o SAM para a imagem carregada
        mask_predictor.set_image(image_rgb)

        # Gerar caixas delimitadoras (simulado ou baseado em ground truth)
        # Substitua a lógica abaixo por sua detecção ou ground truth real
        annotations = COCOJsonUtility.get_annotations_by_image_path(coco_data=coco_data, image_path=filename)

        # Verificar se há anotações
        if annotations is None or len(annotations) == 0:
            print(f"Nenhuma anotação encontrada para: {filename}")
            continue

        ground_truth = COCOJsonUtility.annotations2detections(annotations=annotations)
        ground_truth.class_id = ground_truth.class_id - 1  # Ajustar IDs das classes
        boxes = ground_truth.xyxy

        # Inicializar listas para máscaras e caixas
        all_masks = []
        all_boxes = []

        # Processar cada caixa com SAM
        for box in boxes:
            masks, scores, logits = mask_predictor.predict(
                box=box,
                multimask_output=True
            )
            all_masks.extend(masks)
            all_boxes.extend(sv.mask_to_xyxy(masks=masks))

        # Criar objeto de detecções
        all_detections = sv.Detections(
            xyxy=np.array(all_boxes),
            mask=np.array(all_masks)
        )

        # Anotar imagem com segmentações
        annotated_image = mask_annotator.annotate(scene=image_bgr.copy(), detections=all_detections)
        cv2.imwrite(output_path, annotated_image)

        # Salvar máscaras individualmente
        for i, mask in enumerate(all_masks):
            mask_path = os.path.join(MASKS_FOLDER, f"{os.path.splitext(filename)[0]}_mask_{i}.png")
            cv2.imwrite(mask_path, (mask * 255).astype(np.uint8))  # Salvar máscara binária

        print(f"Resultados salvos: {output_path} | Máscaras: {MASKS_FOLDER}")

print("Processamento concluído!")
# Out:
# Processando: 0-11-24_png_jpg.rf.0914ae816085b671b01c387df2dd7787.jpg
# Nenhuma anotação encontrada para: 0-11-24_png_jpg.rf.0914ae816085b671b01c387df2dd7787.jpg
# Processando: 0-13-19_png_jpg.rf.0802b67da70f9b5bd437aa1139aa1d99.jpg
# Nenhuma anotação encontrada para: 0-13-19_png_jpg.rf.0802b67da70f9b5bd437aa1139aa1d99.jpg
# Processando: 0-13-24_png_jpg.rf.b10c6d74717ffac0937a0e56b90320da.jpg
# Nenhuma anotação encontrada para: 0-13-24_png_jpg.rf.b10c6d74717ffac0937a0e56b90320da.jpg
# Processando: 0-13-24_png_jpg.rf.d7b8e23481af336f5081b102c591be2e.jpg
# Nenhuma anotação encontrada para: 0-13-24_png_jpg.rf.d7b8e23481af336f5081b102c591be2e.jpg
# Processando: 0-13-25_png_jpg.rf.15b87e94de094c41958f666acd54941f.jpg
# Nenhuma anotação encontrada para: 0-13-25_png_jpg.rf.15b87e94de094c41958f666acd54941f.jpg
# Processando: 0-13-25_png_jpg.rf.d6ce7565e97953930b57ba6a6296fb67.jpg
# Nenhuma anotação encontrada para: 0-13-25_png_jpg.rf.d6ce7565e97953930b57ba6a6296fb67.jpg
# Processando: 0-13-35_png_jpg.rf.feb7275bda8ed2fc4200d19cfe3bfc86.jpg
# Nenhuma anotação encontrada para: 0-13-35_png_jpg.rf.feb7275bda8ed2fc4200d19cfe3bfc86.jpg
# Processando: 0-13-35_png_jpg.rf.ffde371a4fadbfcfc0941b00ff1b9072.jpg
# Nenhuma anotação encontrada para: 0-13-35_png_jpg.rf.ffde371a4fadbfcfc0941b00ff1b9072.jpg
# Processando: 0-13-37_png_jpg.rf.2a6ff5e784b4116463b0899ce9d073fb.jpg
# Nenhuma anotação encontrada para: 0-13-37_png_jpg.rf.2a6ff5e784b4116463b0899ce9d073fb.jpg
# Processando: 0-13-37_png_jpg.rf.2c1691489ec339f8749b615a18276008.jpg
# Nenhuma anotação encontrada para: 0-13-37_png_jpg.rf.2c1691489ec339f8749b615a18276008.jpg
# Processando: 0-13-54_png_jpg.rf.12c375a1b250a5788d73edb8510c0e8c.jpg
# Nenhuma anotação encontrada para: 0-13-54_png_jpg.rf.12c375a1b250a5788d73edb8510c0e8c.jpg
# Processando: 0-14-1_png_jpg.rf.865013a7e10bec1dc950173555e89f60.jpg
# Nenhuma anotação encontrada para: 0-14-1_png_jpg.rf.865013a7e10bec1dc950173555e89f60.jpg
# Processando: 0-14-1_png_jpg.rf.8c474687b48c5cf758202d913204195c.jpg
# Nenhuma anotação encontrada para: 0-14-1_png_jpg.rf.8c474687b48c5cf758202d913204195c.jpg
# Processando: 0-32-23_png_jpg.rf.d5145190c17531987cfa0a50e880d750.jpg
# Nenhuma anotação encontrada para: 0-32-23_png_jpg.rf.d5145190c17531987cfa0a50e880d750.jpg
# Processando: 0-32-23_png_jpg.rf.e03dc2d5698c8e8057045184b2ed2602.jpg
# Nenhuma anotação encontrada para: 0-32-23_png_jpg.rf.e03dc2d5698c8e8057045184b2ed2602.jpg
# Processando: 0-32-23_png_jpg.rf.eb5764fd75e6b9780fed420522eeca11.jpg
# Nenhuma anotação encontrada para: 0-32-23_png_jpg.rf.eb5764fd75e6b9780fed420522eeca11.jpg
# Processando: 0-32-23_png_jpg.rf.ed86fb001cba302864c83461e841f9fb.jpg
# Nenhuma anotação encontrada para: 0-32-23_png_jpg.rf.ed86fb001cba302864c83461e841f9fb.jpg
# Processando: 0-32-30_png_jpg.rf.d3f95e4f8f4adfd07f199e5ec8ea88d6.jpg
# Nenhuma anotação encontrada para: 0-32-30_png_jpg.rf.d3f95e4f8f4adfd07f199e5ec8ea88d6.jpg
# Processando: 0-32-30_png_jpg.rf.f66d03efa80f77d54c84230110c3ca1c.jpg
# Nenhuma anotação encontrada para: 0-32-30_png_jpg.rf.f66d03efa80f77d54c84230110c3ca1c.jpg
# Processando: 0-32-31_png_jpg.rf.98b887b2eee6748515850b40261c63d6.jpg
# Nenhuma anotação encontrada para: 0-32-31_png_jpg.rf.98b887b2eee6748515850b40261c63d6.jpg
# Processando: 0-33-46_png_jpg.rf.4743a9408eb03dad512115e67892a075.jpg
# Nenhuma anotação encontrada para: 0-33-46_png_jpg.rf.4743a9408eb03dad512115e67892a075.jpg
# Processando: 0-33-46_png_jpg.rf.4e16c47e9bc53b428d580a9ba2aa7256.jpg
# Nenhuma anotação encontrada para: 0-33-46_png_jpg.rf.4e16c47e9bc53b428d580a9ba2aa7256.jpg
# Processando: 0-33-46_png_jpg.rf.6f4c5016563f5cacedd193601a0404ea.jpg
# Nenhuma anotação encontrada para: 0-33-46_png_jpg.rf.6f4c5016563f5cacedd193601a0404ea.jpg
# Processando: 0-33-46_png_jpg.rf.f61ed20167ea064f173a52e7247844cc.jpg
# Nenhuma anotação encontrada para: 0-33-46_png_jpg.rf.f61ed20167ea064f173a52e7247844cc.jpg
# Processando: 0-33-53_png_jpg.rf.f23a37cda6300e957edd47c801683048.jpg
# Nenhuma anotação encontrada para: 0-33-53_png_jpg.rf.f23a37cda6300e957edd47c801683048.jpg
# Processando: 0-35-23_png_jpg.rf.1d387d6cfa391adcf4bd60ef648bf388.jpg
# Nenhuma anotação encontrada para: 0-35-23_png_jpg.rf.1d387d6cfa391adcf4bd60ef648bf388.jpg
# Processando: 0-35-23_png_jpg.rf.40d8ed6aaf44c234c4b108b276bde6b8.jpg
# Nenhuma anotação encontrada para: 0-35-23_png_jpg.rf.40d8ed6aaf44c234c4b108b276bde6b8.jpg
# Processando: 0-35-23_png_jpg.rf.4509a0ba5442e302cd234709719f1835.jpg
# Nenhuma anotação encontrada para: 0-35-23_png_jpg.rf.4509a0ba5442e302cd234709719f1835.jpg
# Processando: 0-65-37_png_jpg.rf.08e1cccc78a0a5d1568c14984814b3a5.jpg
# Nenhuma anotação encontrada para: 0-65-37_png_jpg.rf.08e1cccc78a0a5d1568c14984814b3a5.jpg
# Processando: 0-65-37_png_jpg.rf.3ab0cff8f706179cfc0886ee72fa565b.jpg
# Nenhuma anotação encontrada para: 0-65-37_png_jpg.rf.3ab0cff8f706179cfc0886ee72fa565b.jpg
# Processando: 0-66-35_png_jpg.rf.0e0881e3bcd6561c57a777808b6dd1c8.jpg
# Nenhuma anotação encontrada para: 0-66-35_png_jpg.rf.0e0881e3bcd6561c57a777808b6dd1c8.jpg
# Processando: 0-67-2_png_jpg.rf.34c0e3eb8c2334c9859f85f856a6596d.jpg
# Nenhuma anotação encontrada para: 0-67-2_png_jpg.rf.34c0e3eb8c2334c9859f85f856a6596d.jpg
# Processando: 0-67-2_png_jpg.rf.69c29968d2b90bae8c61fc6c4c301503.jpg
# Nenhuma anotação encontrada para: 0-67-2_png_jpg.rf.69c29968d2b90bae8c61fc6c4c301503.jpg
# Processando: 0-67-2_png_jpg.rf.9c988645396ab70a3e39be2279eef4e5.jpg
# Nenhuma anotação encontrada para: 0-67-2_png_jpg.rf.9c988645396ab70a3e39be2279eef4e5.jpg
# Processando: 0-67-2_png_jpg.rf.fcdf51c47ad38821ace4aad8b0ab3e8f.jpg
# Nenhuma anotação encontrada para: 0-67-2_png_jpg.rf.fcdf51c47ad38821ace4aad8b0ab3e8f.jpg
# Processando: 0-67-2_png_jpg.rf.fe57ad161748021793d989d473240e4b.jpg
# Nenhuma anotação encontrada para: 0-67-2_png_jpg.rf.fe57ad161748021793d989d473240e4b.jpg
# Processando: 0-68-9_png_jpg.rf.66bf30a139a14d1f90d923ec557f6f17.jpg
# Nenhuma anotação encontrada para: 0-68-9_png_jpg.rf.66bf30a139a14d1f90d923ec557f6f17.jpg
# Processando: 0-68-9_png_jpg.rf.9dad5e3924f3bb99a9070332d85148d2.jpg
# Nenhuma anotação encontrada para: 0-68-9_png_jpg.rf.9dad5e3924f3bb99a9070332d85148d2.jpg
# Processando: 0-68-9_png_jpg.rf.f38ca677e7dfc38f8c8deff7a8736455.jpg
# Nenhuma anotação encontrada para: 0-68-9_png_jpg.rf.f38ca677e7dfc38f8c8deff7a8736455.jpg
# Processando: 0-68-9_png_jpg.rf.f985d20d40ba6844a1b8e54f994432bc.jpg
# Nenhuma anotação encontrada para: 0-68-9_png_jpg.rf.f985d20d40ba6844a1b8e54f994432bc.jpg
# Processando: 0-69-34_png_jpg.rf.16bf23ae08b4150c86a7146372c59047.jpg
# Nenhuma anotação encontrada para: 0-69-34_png_jpg.rf.16bf23ae08b4150c86a7146372c59047.jpg
# Processando: 0-69-34_png_jpg.rf.83659f1b41430aab1cf81b67b615f59d.jpg
# Nenhuma anotação encontrada para: 0-69-34_png_jpg.rf.83659f1b41430aab1cf81b67b615f59d.jpg
# Processando: 0-69-45_png_jpg.rf.a6f7182f5d7026b0abd041bb08eced93.jpg
# Nenhuma anotação encontrada para: bloco_223_jpg.rf.c84323cc24b584cc731a2a21e7cf9249.jpg
# Processando: bloco_239_jpg.rf.a6d8b3d3645d8a2955301904a065f36a.jpg
# Nenhuma anotação encontrada para: bloco_239_jpg.rf.a6d8b3d3645d8a2955301904a065f36a.jpg
# Processando: bloco_241_jpg.rf.ff5619617c01e770aa044a7fb98040e2.jpg
# Nenhuma anotação encontrada para: bloco_241_jpg.rf.ff5619617c01e770aa044a7fb98040e2.jpg
# Processando: bloco_48_jpg.rf.245dfc8a1272365d602b86aa88ae7b27.jpg
# Nenhuma anotação encontrada para: bloco_48_jpg.rf.245dfc8a1272365d602b86aa88ae7b27.jpg
# Processando: bloco_50_jpg.rf.1df6ca987e5d35ba83c67293b07c88a4.jpg
# Nenhuma anotação encontrada para: bloco_50_jpg.rf.1df6ca987e5d35ba83c67293b07c88a4.jpg
# Processando: bloco_50_jpg.rf.664984ed1d267d39d3c5cc37adf838e4.jpg
# Nenhuma anotação encontrada para: bloco_50_jpg.rf.664984ed1d267d39d3c5cc37adf838e4.jpg
# Processando: bloco_50_jpg.rf.ca741155791b13b6f2e30ad591412dc1.jpg
# Nenhuma anotação encontrada para: bloco_50_jpg.rf.ca741155791b13b6f2e30ad591412dc1.jpg
# Processando: bloco_72_jpg.rf.83705344b56dc9262cde339e9afa8619.jpg
# Nenhuma anotação encontrada para: bloco_72_jpg.rf.83705344b56dc9262cde339e9afa8619.jpg
# Processando: bloco_90_jpg.rf.a19ee997d65a24cedc8c7ceac651c5b3.jpg
# Nenhuma anotação encontrada para: bloco_90_jpg.rf.a19ee997d65a24cedc8c7ceac651c5b3.jpg
# Processando: bloco_91_jpg.rf.126fd7ead126055d835049ee3dfe71cf.jpg
# Nenhuma anotação encontrada para: bloco_91_jpg.rf.126fd7ead126055d835049ee3dfe71cf.jpg
# Processando: bloco_91_jpg.rf.57f95dc2c6a2c74733210ef165580149.jpg
# Nenhuma anotação encontrada para: bloco_91_jpg.rf.57f95dc2c6a2c74733210ef165580149.jpg
# Processando: bloco_91_jpg.rf.90e49e44f422f09e9cb51400ebb6e96b.jpg
# Nenhuma anotação encontrada para: bloco_91_jpg.rf.90e49e44f422f09e9cb51400ebb6e96b.jpg
# Processando: evo1105_jpg.rf.24309bced3c9954f69c4e43ed6044f85.jpg
# Nenhuma anotação encontrada para: evo1105_jpg.rf.24309bced3c9954f69c4e43ed6044f85.jpg
# Processando: evo1105_jpg.rf.eaf0914f06d329865448ebefbe479563.jpg
# Nenhuma anotação encontrada para: evo1105_jpg.rf.eaf0914f06d329865448ebefbe479563.jpg
# Processando: evo1109_jpg.rf.66c84c5182be2165ba9e0d7ed34e0075.jpg
# Nenhuma anotação encontrada para: evo1109_jpg.rf.66c84c5182be2165ba9e0d7ed34e0075.jpg
# Processando: evo157_jpg.rf.135f815af3950b29d6b7b0d973414a40.jpg
# Nenhuma anotação encontrada para: evo157_jpg.rf.135f815af3950b29d6b7b0d973414a40.jpg
# Processando: evo157_jpg.rf.6c034124e5372c03f677e381ab54f6ed.jpg
